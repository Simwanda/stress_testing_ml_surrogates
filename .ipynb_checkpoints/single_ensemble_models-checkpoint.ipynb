# %%
# =========================================
# 0) Imports + IO
# =========================================
import os, json, math
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C, WhiteKernel

import optuna

# Optional boosters
HAVE_XGB = HAVE_LGBM = HAVE_CAT = False
try:
    import xgboost as xgb
    HAVE_XGB = True
except Exception:
    pass

try:
    import lightgbm as lgb
    HAVE_LGBM = True
except Exception:
    pass

try:
    from catboost import CatBoostRegressor
    HAVE_CAT = True
except Exception:
    pass

DATA_PATH = "data/data.xlsx"  # adjust if needed
data = pd.read_excel(DATA_PATH)

targets_all = ["M_LB", "M_DB"]
feature_cols = [c for c in data.columns if c not in targets_all]

print("Data shape:", data.shape)
print("Features:", feature_cols)
print("Targets:", targets_all)
# Out:
# Data shape: (432, 14)
# Features: ['D', 'Bf', 'Bl', 't', 'Lsl', 'Wsl', 'Ssl', 'Bsl', 'N', 'n', 'Fy', 'r']
# Targets: ['M_LB', 'M_DB']

# %%
# =========================================
# 1) Config
# =========================================
CFG = {
    "random_state": 42,
    "test_size": 0.20,
    "cv_splits": 10,
    "optuna_trials": 40,     # increase to 80–150 for final runs
    "artdir": "./artifacts",
    "models_to_run": [
        # single / baseline
        "ridge", "lasso", "elasticnet", "dt", "knn", "svr", "gpr",
        # ensembles
        "rf", "gbrt", "adaboost",
        # optional gradient boosters
        "xgb", "lgbm", "catboost"
    ],
    "feature_cols": feature_cols
}

os.makedirs(CFG["artdir"], exist_ok=True)

# Filter optional models if not installed
filtered = []
for mk in CFG["models_to_run"]:
    if mk == "xgb" and not HAVE_XGB:
        continue
    if mk == "lgbm" and not HAVE_LGBM:
        continue
    if mk == "catboost" and not HAVE_CAT:
        continue
    filtered.append(mk)
CFG["models_to_run"] = filtered

print("Models to run:", CFG["models_to_run"])
# Out:
# Models to run: ['ridge', 'lasso', 'elasticnet', 'dt', 'knn', 'svr', 'gpr', 'rf', 'gbrt', 'adaboost', 'xgb', 'lgbm', 'catboost']

# %%
# =========================================
# 2) Preprocessor (safe)
# =========================================
def preprocessor_for(model_key: str, df: pd.DataFrame):
    """
    Numeric-only pipeline.
    - Always imputes median.
    - Scales for distance/linear/kernel models.
    - No scaling for tree/boosting models (optional but typical).
    """
    num_cols = CFG["feature_cols"]

    needs_scaling = model_key in {"ridge", "lasso", "elasticnet", "knn", "svr", "gpr"}

    steps = [("imputer", SimpleImputer(strategy="median"))]
    if needs_scaling:
        steps.append(("scaler", StandardScaler()))

    num_pipe = Pipeline(steps)
    return ColumnTransformer([("num", num_pipe, num_cols)], remainder="drop")

# %%
# =========================================
# 3) Model factory (Optuna-tuned)
# =========================================
def build_model(model_key: str, trial: "optuna.trial.Trial"):
    rs = CFG["random_state"]

    if model_key == "ridge":
        return Ridge(alpha=trial.suggest_float("alpha", 1e-3, 1e3, log=True))

    if model_key == "lasso":
        return Lasso(alpha=trial.suggest_float("alpha", 1e-4, 10.0, log=True),
                     max_iter=8000, random_state=rs)

    if model_key == "elasticnet":
        return ElasticNet(alpha=trial.suggest_float("alpha", 1e-4, 10.0, log=True),
                          l1_ratio=trial.suggest_float("l1_ratio", 0.0, 1.0),
                          max_iter=8000, random_state=rs)

    if model_key == "dt":
        return DecisionTreeRegressor(
            max_depth=trial.suggest_int("max_depth", 2, 40),
            min_samples_split=trial.suggest_int("min_samples_split", 2, 30),
            min_samples_leaf=trial.suggest_int("min_samples_leaf", 1, 20),
            random_state=rs
        )

    if model_key == "knn":
        return KNeighborsRegressor(
            n_neighbors=trial.suggest_int("n_neighbors", 2, 35),
            weights=trial.suggest_categorical("weights", ["uniform", "distance"]),
            p=trial.suggest_int("p", 1, 2)
        )

    if model_key == "rf":
        return RandomForestRegressor(
            n_estimators=trial.suggest_int("n_estimators", 300, 1200, step=100),
            max_depth=trial.suggest_int("max_depth", 3, 40),
            min_samples_split=trial.suggest_int("min_samples_split", 2, 20),
            min_samples_leaf=trial.suggest_int("min_samples_leaf", 1, 10),
            max_features=trial.suggest_float("max_features", 0.3, 1.0),  # valid in new sklearn
            n_jobs=-1,
            random_state=rs
        )

    if model_key == "gbrt":
        return GradientBoostingRegressor(
            n_estimators=trial.suggest_int("n_estimators", 200, 1500, step=100),
            max_depth=trial.suggest_int("max_depth", 2, 6),
            learning_rate=trial.suggest_float("learning_rate", 1e-3, 0.3, log=True),
            subsample=trial.suggest_float("subsample", 0.6, 1.0),
            random_state=rs
        )

    if model_key == "adaboost":
        return AdaBoostRegressor(
            n_estimators=trial.suggest_int("n_estimators", 100, 1000, step=50),
            learning_rate=trial.suggest_float("learning_rate", 1e-3, 2.0, log=True),
            random_state=rs
        )

    if model_key == "svr":
        return SVR(
            C=trial.suggest_float("C", 1e-2, 1e3, log=True),
            epsilon=trial.suggest_float("epsilon", 1e-3, 1.0, log=True),
            gamma=trial.suggest_categorical("gamma", ["scale", "auto"]),
            kernel=trial.suggest_categorical("kernel", ["rbf", "poly", "sigmoid"])
        )

    if model_key == "xgb":
        if not HAVE_XGB:
            raise ValueError("xgboost not installed.")
        return xgb.XGBRegressor(
            n_estimators=trial.suggest_int("n_estimators", 300, 2000, step=100),
            max_depth=trial.suggest_int("max_depth", 3, 12),
            learning_rate=trial.suggest_float("learning_rate", 1e-3, 0.3, log=True),
            subsample=trial.suggest_float("subsample", 0.5, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.5, 1.0),
            reg_alpha=trial.suggest_float("reg_alpha", 1e-8, 10.0, log=True),
            reg_lambda=trial.suggest_float("reg_lambda", 1e-8, 10.0, log=True),
            min_child_weight=trial.suggest_float("min_child_weight", 1e-2, 10.0, log=True),
            tree_method="hist",
            random_state=rs,
            n_jobs=-1
        )

    if model_key == "lgbm":
        if not HAVE_LGBM:
            raise ValueError("lightgbm not installed.")
        return lgb.LGBMRegressor(
            n_estimators=trial.suggest_int("n_estimators", 300, 2000, step=100),
            num_leaves=trial.suggest_int("num_leaves", 15, 255),
            max_depth=trial.suggest_int("max_depth", -1, 32),
            learning_rate=trial.suggest_float("learning_rate", 1e-3, 0.3, log=True),
            subsample=trial.suggest_float("subsample", 0.6, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.6, 1.0),
            min_child_samples=trial.suggest_int("min_child_samples", 5, 100),
            reg_alpha=trial.suggest_float("reg_alpha", 1e-8, 10.0, log=True),
            reg_lambda=trial.suggest_float("reg_lambda", 1e-8, 10.0, log=True),
            random_state=rs,
            n_jobs=-1
        )

    if model_key == "catboost":
        if not HAVE_CAT:
            raise ValueError("catboost not installed.")
        return CatBoostRegressor(
            depth=trial.suggest_int("depth", 4, 10),
            learning_rate=trial.suggest_float("learning_rate", 1e-3, 0.3, log=True),
            l2_leaf_reg=trial.suggest_float("l2_leaf_reg", 1.0, 10.0),
            n_estimators=trial.suggest_int("n_estimators", 300, 2000, step=100),
            loss_function="RMSE",
            random_state=rs,
            verbose=False
        )

    if model_key == "gpr":
        length_scale = trial.suggest_float("length_scale", 0.1, 10.0, log=True)
        noise = trial.suggest_float("noise", 1e-6, 1e-1, log=True)
        kernel = C(1.0, (1e-3, 1e3)) * RBF(length_scale=length_scale) + WhiteKernel(noise_level=noise)
        return GaussianProcessRegressor(kernel=kernel, alpha=0.0, normalize_y=True, random_state=rs)

    raise ValueError(f"Unknown model_key={model_key}")

# %%
# =========================================
# 4) Utilities
# =========================================
def rmse(y_true, y_pred) -> float:
    return float(np.sqrt(mean_squared_error(y_true, y_pred)))

def tune_and_eval_one_target(target_col: str):
    X = data[CFG["feature_cols"]].copy()
    y = data[target_col].astype(float).copy()

    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=CFG["test_size"], random_state=CFG["random_state"]
    )

    results = {}
    best_pipes = {}

    for model_key in CFG["models_to_run"]:
        print(f"\n=== Tuning {model_key.upper()} for {target_col} ===")

        def objective(trial):
            model = build_model(model_key, trial)
            preproc = preprocessor_for(model_key, df=data)
            pipe = Pipeline([("preprocessor", preproc), ("model", model)])

            cv = KFold(n_splits=CFG["cv_splits"], shuffle=True, random_state=CFG["random_state"])
            scores = cross_val_score(
                pipe, X_train, y_train,
                scoring="neg_root_mean_squared_error",
                cv=cv, n_jobs=-1
            )
            return -float(np.mean(scores))  # minimize RMSE

        study = optuna.create_study(direction="minimize", study_name=f"{model_key}_{target_col}")
        study.optimize(objective, n_trials=CFG["optuna_trials"], show_progress_bar=False)

        best_model = build_model(model_key, study.best_trial)
        preproc = preprocessor_for(model_key, df=data)
        best_pipe = Pipeline([("preprocessor", preproc), ("model", best_model)])
        best_pipe.fit(X_train, y_train)

        y_pred = best_pipe.predict(X_test)

        results[model_key] = {
            "rmse": rmse(y_test, y_pred),
            "mae": float(mean_absolute_error(y_test, y_pred)),
            "r2": float(r2_score(y_test, y_pred)),
            "best_params": study.best_trial.params
        }
        best_pipes[model_key] = best_pipe

    # Save results
    out_json = os.path.join(CFG["artdir"], f"results_{target_col}.json")
    out_csv  = os.path.join(CFG["artdir"], f"results_{target_col}.csv")

    with open(out_json, "w") as f:
        json.dump(results, f, indent=2)

    pd.DataFrame(results).T.sort_values("rmse").to_csv(out_csv, index=True)

    print(f"\n[done] {target_col}: saved {out_json} and {out_csv}")
    return results, best_pipes

# %%
# =========================================
# 5) Run for BOTH targets (M_LB and M_DB)
# =========================================
all_results = {}
all_best_pipes = {}

for tgt in ["M_LB", "M_DB"]:
    res, pipes = tune_and_eval_one_target(tgt)
    all_results[tgt] = res
    all_best_pipes[tgt] = pipes

# quick leaderboard
for tgt in all_results:
    print("\n=== Leaderboard (lowest RMSE) for", tgt, "===")
    df_res = pd.DataFrame(all_results[tgt]).T.sort_values("rmse")
    display(df_res[["rmse", "mae", "r2"]].head(10))
# Out:
# [I 2026-03-06 16:29:57,529] A new study created in memory with name: ridge_M_LB
# === Tuning RIDGE for M_LB ===
# [I 2026-03-06 16:30:03,123] Trial 0 finished with value: 6.082085738816052 and parameters: {'alpha': 495.2372727569729}. Best is trial 0 with value: 6.082085738816052.
# [I 2026-03-06 16:30:03,188] Trial 1 finished with value: 4.033291756088787 and parameters: {'alpha': 91.8238954481189}. Best is trial 1 with value: 4.033291756088787.
# [I 2026-03-06 16:30:03,236] Trial 2 finished with value: 3.775009212966674 and parameters: {'alpha': 4.380219360611655}. Best is trial 2 with value: 3.775009212966674.
# [I 2026-03-06 16:30:03,283] Trial 3 finished with value: 3.7785497145242517 and parameters: {'alpha': 0.02000015535532205}. Best is trial 2 with value: 3.775009212966674.
# [I 2026-03-06 16:30:03,335] Trial 4 finished with value: 3.7784687770223186 and parameters: {'alpha': 0.08799664502349105}. Best is trial 2 with value: 3.775009212966674.
# [I 2026-03-06 16:30:03,429] Trial 5 finished with value: 3.7769628231045203 and parameters: {'alpha': 1.5219686958551257}. Best is trial 2 with value: 3.775009212966674.
# [I 2026-03-06 16:30:03,547] Trial 6 finished with value: 3.7747741160707493 and parameters: {'alpha': 10.516083804353865}. Best is trial 6 with value: 3.7747741160707493.
# [I 2026-03-06 16:30:03,711] Trial 7 finished with value: 3.7784944040643476 and parameters: {'alpha': 0.06638596312380919}. Best is trial 6 with value: 3.7747741160707493.
# [I 2026-03-06 16:30:03,789] Trial 8 finished with value: 3.7784997167713157 and parameters: {'alpha': 0.061915344497211325}. Best is trial 6 with value: 3.7747741160707493.
# [I 2026-03-06 16:30:03,949] Trial 9 finished with value: 3.7785723601468364 and parameters: {'alpha': 0.001108350824141924}. Best is trial 6 with value: 3.7747741160707493.
# [I 2026-03-06 16:30:04,090] Trial 10 finished with value: 3.7841768907788245 and parameters: {'alpha': 20.96777770424166}. Best is trial 6 with value: 3.7747741160707493.
# [I 2026-03-06 16:30:04,196] Trial 11 finished with value: 3.7747587434233076 and parameters: {'alpha': 4.985937898826226}. Best is trial 11 with value: 3.7747587434233076.
# [I 2026-03-06 16:30:04,352] Trial 12 finished with value: 3.7755514735575604 and parameters: {'alpha': 12.252271046786642}. Best is trial 11 with value: 3.7747587434233076.
# [I 2026-03-06 16:30:04,442] Trial 13 finished with value: 3.7779836900997585 and parameters: {'alpha': 0.5122550340620973}. Best is trial 11 with value: 3.7747587434233076.
# [I 2026-03-06 16:30:04,503] Trial 14 finished with value: 4.142376404866424 and parameters: {'alpha': 113.03376832832171}. Best is trial 11 with value: 3.7747587434233076.
# [I 2026-03-06 16:30:04,565] Trial 15 finished with value: 3.77777989830879 and parameters: {'alpha': 0.6999260176150518}. Best is trial 11 with value: 3.7747587434233076.
# [I 2026-03-06 16:30:04,623] Trial 16 finished with value: 3.812801807426869 and parameters: {'alpha': 35.41326323038375}. Best is trial 11 with value: 3.7747587434233076.
# [I 2026-03-06 16:30:04,687] Trial 17 finished with value: 7.054912571485451 and parameters: {'alpha': 801.1689018184215}. Best is trial 11 with value: 3.7747587434233076.
# [I 2026-03-06 16:30:04,747] Trial 18 finished with value: 3.776956443452871 and parameters: {'alpha': 1.5289025338423041}. Best is trial 11 with value: 3.7747587434233076.
# [I 2026-03-06 16:30:04,805] Trial 19 finished with value: 3.7745260512147825 and parameters: {'alpha': 5.722040663883582}. Best is trial 19 with value: 3.7745260512147825.
# [I 2026-03-06 16:30:04,855] Trial 20 finished with value: 3.7754668881169295 and parameters: {'alpha': 3.5079622565119704}. Best is trial 19 with value: 3.7745260512147825.
# [I 2026-03-06 16:30:04,907] Trial 21 finished with value: 3.774302315944058 and parameters: {'alpha': 6.9919991586784}. Best is trial 21 with value: 3.774302315944058.
# [I 2026-03-06 16:30:04,958] Trial 22 finished with value: 3.77832458716097 and parameters: {'alpha': 0.21102781349306524}. Best is trial 21 with value: 3.774302315944058.
# [I 2026-03-06 16:30:05,006] Trial 23 finished with value: 4.051759599524774 and parameters: {'alpha': 95.54611080711192}. Best is trial 21 with value: 3.774302315944058.
# [I 2026-03-06 16:30:05,067] Trial 24 finished with value: 3.7749629395915703 and parameters: {'alpha': 4.482878791322963}. Best is trial 21 with value: 3.774302315944058.
# [I 2026-03-06 16:30:05,139] Trial 25 finished with value: 3.7951156272933986 and parameters: {'alpha': 27.489472884706345}. Best is trial 21 with value: 3.774302315944058.
# [I 2026-03-06 16:30:05,203] Trial 26 finished with value: 3.7749202902608987 and parameters: {'alpha': 4.580742037211711}. Best is trial 21 with value: 3.774302315944058.
# [I 2026-03-06 16:30:05,259] Trial 27 finished with value: 4.780127076753502 and parameters: {'alpha': 225.24761582884946}. Best is trial 21 with value: 3.774302315944058.
# [I 2026-03-06 16:30:05,308] Trial 28 finished with value: 3.7782003589687903 and parameters: {'alpha': 0.31905761603716093}. Best is trial 21 with value: 3.774302315944058.
# [I 2026-03-06 16:30:05,354] Trial 29 finished with value: 3.7765618003290333 and parameters: {'alpha': 1.9770731175369982}. Best is trial 21 with value: 3.774302315944058.
# [I 2026-03-06 16:30:05,405] Trial 30 finished with value: 5.099159639578028 and parameters: {'alpha': 283.0049525470126}. Best is trial 21 with value: 3.774302315944058.
# [I 2026-03-06 16:30:05,454] Trial 31 finished with value: 3.7749342907589787 and parameters: {'alpha': 10.945225577226534}. Best is trial 21 with value: 3.774302315944058.
# [I 2026-03-06 16:30:05,505] Trial 32 finished with value: 3.7754658663304674 and parameters: {'alpha': 12.092707079515701}. Best is trial 21 with value: 3.774302315944058.
# [I 2026-03-06 16:30:05,554] Trial 33 finished with value: 3.9174273846296224 and parameters: {'alpha': 66.34365562256552}. Best is trial 21 with value: 3.774302315944058.
# [I 2026-03-06 16:30:05,606] Trial 34 finished with value: 3.774279735211837 and parameters: {'alpha': 8.036676085417417}. Best is trial 34 with value: 3.774279735211837.
# [I 2026-03-06 16:30:05,653] Trial 35 finished with value: 3.7755451669738753 and parameters: {'alpha': 3.37796869814364}. Best is trial 34 with value: 3.774279735211837.
# [I 2026-03-06 16:30:05,704] Trial 36 finished with value: 3.7774432635948316 and parameters: {'alpha': 1.023984263817752}. Best is trial 34 with value: 3.774279735211837.
# [I 2026-03-06 16:30:05,774] Trial 37 finished with value: 3.8548715515407443 and parameters: {'alpha': 49.67553498217851}. Best is trial 34 with value: 3.774279735211837.
# [I 2026-03-06 16:30:05,840] Trial 38 finished with value: 3.7745080222982508 and parameters: {'alpha': 5.791676595672261}. Best is trial 34 with value: 3.774279735211837.
# [I 2026-03-06 16:30:05,894] Trial 39 finished with value: 3.778557110143711 and parameters: {'alpha': 0.01382412889025804}. Best is trial 34 with value: 3.774279735211837.
# [I 2026-03-06 16:30:05,920] A new study created in memory with name: lasso_M_LB
# [I 2026-03-06 16:30:05,983] Trial 0 finished with value: 3.7782537830535006 and parameters: {'alpha': 0.0013610911829005626}. Best is trial 0 with value: 3.7782537830535006.
# [I 2026-03-06 16:30:06,043] Trial 1 finished with value: 3.7706985663807777 and parameters: {'alpha': 0.03648055580635139}. Best is trial 1 with value: 3.7706985663807777.
# [I 2026-03-06 16:30:06,105] Trial 2 finished with value: 4.490668144938503 and parameters: {'alpha': 1.4289175066611106}. Best is trial 1 with value: 3.7706985663807777.
# === Tuning LASSO for M_LB ===
# [I 2026-03-06 16:30:06,168] Trial 3 finished with value: 3.9519306706328576 and parameters: {'alpha': 0.7327124698358558}. Best is trial 1 with value: 3.7706985663807777.
# [I 2026-03-06 16:30:06,216] Trial 4 finished with value: 7.054181496521082 and parameters: {'alpha': 3.5316116719015618}. Best is trial 1 with value: 3.7706985663807777.
# [I 2026-03-06 16:30:06,273] Trial 5 finished with value: 3.7784126781184084 and parameters: {'alpha': 0.0007504552215812825}. Best is trial 1 with value: 3.7706985663807777.
# [I 2026-03-06 16:30:06,327] Trial 6 finished with value: 10.834531002973346 and parameters: {'alpha': 8.884475092642482}. Best is trial 1 with value: 3.7706985663807777.
# [I 2026-03-06 16:30:06,379] Trial 7 finished with value: 3.7684244955349113 and parameters: {'alpha': 0.05138139748283336}. Best is trial 7 with value: 3.7684244955349113.
# [I 2026-03-06 16:30:06,442] Trial 8 finished with value: 3.7764191185009066 and parameters: {'alpha': 0.008855384318435782}. Best is trial 7 with value: 3.7684244955349113.
# [I 2026-03-06 16:30:06,496] Trial 9 finished with value: 3.776552362885687 and parameters: {'alpha': 0.00829146485446235}. Best is trial 7 with value: 3.7684244955349113.
# [I 2026-03-06 16:30:06,550] Trial 10 finished with value: 3.7679833849860755 and parameters: {'alpha': 0.13150905385718364}. Best is trial 10 with value: 3.7679833849860755.
# [I 2026-03-06 16:30:06,603] Trial 11 finished with value: 3.7676281089425827 and parameters: {'alpha': 0.12703654809182024}. Best is trial 11 with value: 3.7676281089425827.
# [I 2026-03-06 16:30:06,654] Trial 12 finished with value: 3.776774320632394 and parameters: {'alpha': 0.18915447713404823}. Best is trial 11 with value: 3.7676281089425827.
# [I 2026-03-06 16:30:06,703] Trial 13 finished with value: 3.7843199742473965 and parameters: {'alpha': 0.24420250308150263}. Best is trial 11 with value: 3.7676281089425827.
# [I 2026-03-06 16:30:06,756] Trial 14 finished with value: 3.768762751235198 and parameters: {'alpha': 0.14006372273705697}. Best is trial 11 with value: 3.7676281089425827.
# [I 2026-03-06 16:30:06,804] Trial 15 finished with value: 3.7771932149425753 and parameters: {'alpha': 0.005621002695674711}. Best is trial 11 with value: 3.7676281089425827.
# [I 2026-03-06 16:30:06,852] Trial 16 finished with value: 3.880272611814136 and parameters: {'alpha': 0.5835267192472666}. Best is trial 11 with value: 3.7676281089425827.
# [I 2026-03-06 16:30:06,898] Trial 17 finished with value: 3.778516420238103 and parameters: {'alpha': 0.00023641500006449403}. Best is trial 11 with value: 3.7676281089425827.
# [I 2026-03-06 16:30:06,948] Trial 18 finished with value: 3.7669825729963313 and parameters: {'alpha': 0.06831163280042168}. Best is trial 18 with value: 3.7669825729963313.
# [I 2026-03-06 16:30:07,000] Trial 19 finished with value: 3.773810969859383 and parameters: {'alpha': 0.020092587073407265}. Best is trial 18 with value: 3.7669825729963313.
# [I 2026-03-06 16:30:07,050] Trial 20 finished with value: 3.778022301322691 and parameters: {'alpha': 0.0022628337901774687}. Best is trial 18 with value: 3.7669825729963313.
# [I 2026-03-06 16:30:07,102] Trial 21 finished with value: 3.766272913711192 and parameters: {'alpha': 0.08423253967691305}. Best is trial 21 with value: 3.766272913711192.
# [I 2026-03-06 16:30:07,159] Trial 22 finished with value: 3.768083237630703 and parameters: {'alpha': 0.05437520862448307}. Best is trial 21 with value: 3.766272913711192.
# [I 2026-03-06 16:30:07,207] Trial 23 finished with value: 3.774433077266483 and parameters: {'alpha': 0.017273271081947962}. Best is trial 21 with value: 3.766272913711192.
# [I 2026-03-06 16:30:07,262] Trial 24 finished with value: 3.8205261136062822 and parameters: {'alpha': 0.4163856384189}. Best is trial 21 with value: 3.766272913711192.
# [I 2026-03-06 16:30:07,322] Trial 25 finished with value: 3.7664613357306407 and parameters: {'alpha': 0.07825342678648599}. Best is trial 21 with value: 3.766272913711192.
# [I 2026-03-06 16:30:07,378] Trial 26 finished with value: 3.76679660715126 and parameters: {'alpha': 0.07150992408228916}. Best is trial 21 with value: 3.766272913711192.
# [I 2026-03-06 16:30:07,440] Trial 27 finished with value: 4.209410566809381 and parameters: {'alpha': 1.1151515868778819}. Best is trial 21 with value: 3.766272913711192.
# [I 2026-03-06 16:30:07,491] Trial 28 finished with value: 3.7750205016698097 and parameters: {'alpha': 0.014877416415681095}. Best is trial 21 with value: 3.766272913711192.
# [I 2026-03-06 16:30:07,552] Trial 29 finished with value: 3.7777494954495503 and parameters: {'alpha': 0.0033561549677803967}. Best is trial 21 with value: 3.766272913711192.
# [I 2026-03-06 16:30:07,607] Trial 30 finished with value: 3.792594455331341 and parameters: {'alpha': 0.3021171737878103}. Best is trial 21 with value: 3.766272913711192.
# [I 2026-03-06 16:30:07,664] Trial 31 finished with value: 3.766783389024021 and parameters: {'alpha': 0.07175093951748654}. Best is trial 21 with value: 3.766272913711192.
# [I 2026-03-06 16:30:07,718] Trial 32 finished with value: 3.7668023031622546 and parameters: {'alpha': 0.07140668853764606}. Best is trial 21 with value: 3.766272913711192.
# [I 2026-03-06 16:30:07,768] Trial 33 finished with value: 3.7702616583682653 and parameters: {'alpha': 0.03890311206560068}. Best is trial 21 with value: 3.766272913711192.
# [I 2026-03-06 16:30:07,813] Trial 34 finished with value: 3.772343168520423 and parameters: {'alpha': 0.027855558977882208}. Best is trial 21 with value: 3.766272913711192.
# [I 2026-03-06 16:30:07,863] Trial 35 finished with value: 3.766277258447675 and parameters: {'alpha': 0.09386314733412102}. Best is trial 21 with value: 3.766272913711192.
# [I 2026-03-06 16:30:07,918] Trial 36 finished with value: 4.996193014321941 and parameters: {'alpha': 1.8906876300816113}. Best is trial 21 with value: 3.766272913711192.
# [I 2026-03-06 16:30:07,964] Trial 37 finished with value: 3.8591576582437925 and parameters: {'alpha': 0.5310869928906956}. Best is trial 21 with value: 3.766272913711192.
# [I 2026-03-06 16:30:08,018] Trial 38 finished with value: 3.7666547133384407 and parameters: {'alpha': 0.10973387472352622}. Best is trial 21 with value: 3.766272913711192.
# [I 2026-03-06 16:30:08,072] Trial 39 finished with value: 7.153937279236411 and parameters: {'alpha': 3.6321333207330864}. Best is trial 21 with value: 3.766272913711192.
# [I 2026-03-06 16:30:08,087] A new study created in memory with name: elasticnet_M_LB
# [I 2026-03-06 16:30:08,147] Trial 0 finished with value: 5.312265543385926 and parameters: {'alpha': 1.6269358002043321, 'l1_ratio': 0.6581617666084175}. Best is trial 0 with value: 5.312265543385926.
# [I 2026-03-06 16:30:08,208] Trial 1 finished with value: 3.7776441610540212 and parameters: {'alpha': 0.002688777140463448, 'l1_ratio': 0.0255860794855447}. Best is trial 1 with value: 3.7776441610540212.
# [I 2026-03-06 16:30:08,262] Trial 2 finished with value: 3.7777107006766237 and parameters: {'alpha': 0.002686983359561446, 'l1_ratio': 0.3240207884061773}. Best is trial 1 with value: 3.7776441610540212.
# === Tuning ELASTICNET for M_LB ===
# [I 2026-03-06 16:30:08,326] Trial 3 finished with value: 3.778303143585987 and parameters: {'alpha': 0.000792578006393909, 'l1_ratio': 0.20512908430358445}. Best is trial 1 with value: 3.7776441610540212.
# [I 2026-03-06 16:30:08,376] Trial 4 finished with value: 3.767443758497327 and parameters: {'alpha': 0.0686885400936521, 'l1_ratio': 0.7457589677517634}. Best is trial 4 with value: 3.767443758497327.
# [I 2026-03-06 16:30:08,423] Trial 5 finished with value: 3.898068797916319 and parameters: {'alpha': 0.21731834398902014, 'l1_ratio': 0.10958976488994354}. Best is trial 4 with value: 3.767443758497327.
# [I 2026-03-06 16:30:08,474] Trial 6 finished with value: 3.777832951729457 and parameters: {'alpha': 0.0025175170873444307, 'l1_ratio': 0.6372018703656377}. Best is trial 4 with value: 3.767443758497327.
# [I 2026-03-06 16:30:08,520] Trial 7 finished with value: 3.931157488644291 and parameters: {'alpha': 0.31325828843090353, 'l1_ratio': 0.3841762326028002}. Best is trial 4 with value: 3.767443758497327.
# [I 2026-03-06 16:30:08,568] Trial 8 finished with value: 4.287361104687722 and parameters: {'alpha': 0.5033007605758689, 'l1_ratio': 0.14251872982032077}. Best is trial 4 with value: 3.767443758497327.
# [I 2026-03-06 16:30:08,616] Trial 9 finished with value: 3.7941037645000213 and parameters: {'alpha': 0.24592146512233684, 'l1_ratio': 0.865923293279511}. Best is trial 4 with value: 3.767443758497327.
# [I 2026-03-06 16:30:08,669] Trial 10 finished with value: 9.787295444904823 and parameters: {'alpha': 7.341704978755944, 'l1_ratio': 0.9796307303887705}. Best is trial 4 with value: 3.767443758497327.
# [I 2026-03-06 16:30:08,721] Trial 11 finished with value: 3.7714241414475884 and parameters: {'alpha': 0.03129011952317804, 'l1_ratio': 0.6730044656251061}. Best is trial 4 with value: 3.767443758497327.
# [I 2026-03-06 16:30:08,775] Trial 12 finished with value: 3.772428280910355 and parameters: {'alpha': 0.025346036206093388, 'l1_ratio': 0.6888059040228581}. Best is trial 4 with value: 3.767443758497327.
# [I 2026-03-06 16:30:08,833] Trial 13 finished with value: 3.7706393451756823 and parameters: {'alpha': 0.0355751127936381, 'l1_ratio': 0.8148969787039965}. Best is trial 4 with value: 3.767443758497327.
# [I 2026-03-06 16:30:08,892] Trial 14 finished with value: 3.7749338830433388 and parameters: {'alpha': 0.014371111261674315, 'l1_ratio': 0.8377467956475295}. Best is trial 4 with value: 3.767443758497327.
# [I 2026-03-06 16:30:09,030] Trial 15 finished with value: 3.778506220602135 and parameters: {'alpha': 0.0002192942206592126, 'l1_ratio': 0.5116133531661057}. Best is trial 4 with value: 3.767443758497327.
# [I 2026-03-06 16:30:09,089] Trial 16 finished with value: 3.767107076165046 and parameters: {'alpha': 0.07169824672635992, 'l1_ratio': 0.7748370383283048}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:09,148] Trial 17 finished with value: 3.7702609052557805 and parameters: {'alpha': 0.06702958502721715, 'l1_ratio': 0.5342077174943457}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:09,214] Trial 18 finished with value: 4.692987602306499 and parameters: {'alpha': 1.561375341472234, 'l1_ratio': 0.9639671911224447}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:09,285] Trial 19 finished with value: 3.7768485336024185 and parameters: {'alpha': 0.006310558940085531, 'l1_ratio': 0.7610109571087267}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:09,353] Trial 20 finished with value: 3.779064056169465 and parameters: {'alpha': 0.09891493544146794, 'l1_ratio': 0.4111876218074896}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:09,414] Trial 21 finished with value: 3.7702466543493878 and parameters: {'alpha': 0.06763979458410617, 'l1_ratio': 0.5363022138764871}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:09,473] Trial 22 finished with value: 3.7712268443426273 and parameters: {'alpha': 0.08774299556016556, 'l1_ratio': 0.5739266553395517}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:09,530] Trial 23 finished with value: 4.403553960462373 and parameters: {'alpha': 0.9809640860599275, 'l1_ratio': 0.7460021852185676}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:09,595] Trial 24 finished with value: 3.7761915655579954 and parameters: {'alpha': 0.009273613930943121, 'l1_ratio': 0.8894976947414486}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:09,653] Trial 25 finished with value: 3.77595904133575 and parameters: {'alpha': 0.1155853290250855, 'l1_ratio': 0.5849815162811529}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:09,707] Trial 26 finished with value: 8.033744241406131 and parameters: {'alpha': 4.330699024990572, 'l1_ratio': 0.4462013470739439}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:09,762] Trial 27 finished with value: 4.338824382810987 and parameters: {'alpha': 0.6074806039626663, 'l1_ratio': 0.3035167226941874}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:09,823] Trial 28 finished with value: 3.768546032731385 and parameters: {'alpha': 0.05096818971813579, 'l1_ratio': 0.7553432227499748}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:09,883] Trial 29 finished with value: 3.774467567895443 and parameters: {'alpha': 0.01608723133399712, 'l1_ratio': 0.7483536054335006}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:09,955] Trial 30 finished with value: 3.777156954620812 and parameters: {'alpha': 0.00545603119045049, 'l1_ratio': 0.9193500791895671}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:10,022] Trial 31 finished with value: 3.770044482695782 and parameters: {'alpha': 0.04298561743769695, 'l1_ratio': 0.6303107224942681}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:10,086] Trial 32 finished with value: 3.7699110235301725 and parameters: {'alpha': 0.040234275176375144, 'l1_ratio': 0.7827364206015583}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:10,155] Trial 33 finished with value: 3.777659320777405 and parameters: {'alpha': 0.16187789859935484, 'l1_ratio': 0.7858952926637628}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:10,229] Trial 34 finished with value: 3.7735448856637026 and parameters: {'alpha': 0.020108262128508386, 'l1_ratio': 0.7170989463795174}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:10,303] Trial 35 finished with value: 3.778271601394722 and parameters: {'alpha': 0.0012426755962890138, 'l1_ratio': 0.9224488956901333}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:10,375] Trial 36 finished with value: 3.776306540401869 and parameters: {'alpha': 0.008586526020730546, 'l1_ratio': 0.820015394807017}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:10,450] Trial 37 finished with value: 3.769434515053016 and parameters: {'alpha': 0.054117267079216845, 'l1_ratio': 0.5989982436073427}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:10,525] Trial 38 finished with value: 3.8852008941820477 and parameters: {'alpha': 0.3331131898555543, 'l1_ratio': 0.5924011268447603}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:10,604] Trial 39 finished with value: 3.7775303033182617 and parameters: {'alpha': 0.003597139581979486, 'l1_ratio': 0.6520250157870187}. Best is trial 16 with value: 3.767107076165046.
# [I 2026-03-06 16:30:10,619] A new study created in memory with name: dt_M_LB
# [I 2026-03-06 16:30:10,699] Trial 0 finished with value: 0.745327078070171 and parameters: {'max_depth': 33, 'min_samples_split': 11, 'min_samples_leaf': 6}. Best is trial 0 with value: 0.745327078070171.
# [I 2026-03-06 16:30:10,760] Trial 1 finished with value: 1.1620875906633048 and parameters: {'max_depth': 38, 'min_samples_split': 29, 'min_samples_leaf': 7}. Best is trial 0 with value: 0.745327078070171.
# === Tuning DT for M_LB ===
# [I 2026-03-06 16:30:10,821] Trial 2 finished with value: 2.6182856196326325 and parameters: {'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 17}. Best is trial 0 with value: 0.745327078070171.
# [I 2026-03-06 16:30:10,876] Trial 3 finished with value: 0.745327078070171 and parameters: {'max_depth': 36, 'min_samples_split': 9, 'min_samples_leaf': 6}. Best is trial 0 with value: 0.745327078070171.
# [I 2026-03-06 16:30:10,933] Trial 4 finished with value: 1.2853194821964649 and parameters: {'max_depth': 17, 'min_samples_split': 4, 'min_samples_leaf': 12}. Best is trial 0 with value: 0.745327078070171.
# [I 2026-03-06 16:30:10,984] Trial 5 finished with value: 1.3378938171997325 and parameters: {'max_depth': 29, 'min_samples_split': 27, 'min_samples_leaf': 12}. Best is trial 0 with value: 0.745327078070171.
# [I 2026-03-06 16:30:11,055] Trial 6 finished with value: 4.360043664413665 and parameters: {'max_depth': 23, 'min_samples_split': 8, 'min_samples_leaf': 20}. Best is trial 0 with value: 0.745327078070171.
# [I 2026-03-06 16:30:11,117] Trial 7 finished with value: 0.4516331438256021 and parameters: {'max_depth': 20, 'min_samples_split': 14, 'min_samples_leaf': 1}. Best is trial 7 with value: 0.4516331438256021.
# [I 2026-03-06 16:30:11,179] Trial 8 finished with value: 0.6067001471874917 and parameters: {'max_depth': 35, 'min_samples_split': 15, 'min_samples_leaf': 2}. Best is trial 7 with value: 0.4516331438256021.
# [I 2026-03-06 16:30:11,241] Trial 9 finished with value: 1.2884605148159678 and parameters: {'max_depth': 40, 'min_samples_split': 30, 'min_samples_leaf': 9}. Best is trial 7 with value: 0.4516331438256021.
# [I 2026-03-06 16:30:11,306] Trial 10 finished with value: 6.837597274529797 and parameters: {'max_depth': 2, 'min_samples_split': 21, 'min_samples_leaf': 1}. Best is trial 7 with value: 0.4516331438256021.
# [I 2026-03-06 16:30:11,369] Trial 11 finished with value: 0.6067001471874917 and parameters: {'max_depth': 19, 'min_samples_split': 15, 'min_samples_leaf': 1}. Best is trial 7 with value: 0.4516331438256021.
# [I 2026-03-06 16:30:11,428] Trial 12 finished with value: 0.8106178685238694 and parameters: {'max_depth': 27, 'min_samples_split': 18, 'min_samples_leaf': 3}. Best is trial 7 with value: 0.4516331438256021.
# [I 2026-03-06 16:30:11,489] Trial 13 finished with value: 0.542090580182948 and parameters: {'max_depth': 13, 'min_samples_split': 14, 'min_samples_leaf': 4}. Best is trial 7 with value: 0.4516331438256021.
# [I 2026-03-06 16:30:11,540] Trial 14 finished with value: 0.8801842204228597 and parameters: {'max_depth': 13, 'min_samples_split': 23, 'min_samples_leaf': 4}. Best is trial 7 with value: 0.4516331438256021.
# [I 2026-03-06 16:30:11,594] Trial 15 finished with value: 0.8821548186395232 and parameters: {'max_depth': 11, 'min_samples_split': 13, 'min_samples_leaf': 9}. Best is trial 7 with value: 0.4516331438256021.
# [I 2026-03-06 16:30:11,648] Trial 16 finished with value: 0.8692070285180307 and parameters: {'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 7 with value: 0.4516331438256021.
# [I 2026-03-06 16:30:11,700] Trial 17 finished with value: 1.7939068948927062 and parameters: {'max_depth': 16, 'min_samples_split': 18, 'min_samples_leaf': 14}. Best is trial 7 with value: 0.4516331438256021.
# [I 2026-03-06 16:30:11,758] Trial 18 finished with value: 0.8801842204228597 and parameters: {'max_depth': 23, 'min_samples_split': 23, 'min_samples_leaf': 4}. Best is trial 7 with value: 0.4516331438256021.
# [I 2026-03-06 16:30:11,818] Trial 19 finished with value: 0.8761177015756634 and parameters: {'max_depth': 13, 'min_samples_split': 12, 'min_samples_leaf': 8}. Best is trial 7 with value: 0.4516331438256021.
# [I 2026-03-06 16:30:11,872] Trial 20 finished with value: 0.593922593539829 and parameters: {'max_depth': 26, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 7 with value: 0.4516331438256021.
# [I 2026-03-06 16:30:11,930] Trial 21 finished with value: 0.593922593539829 and parameters: {'max_depth': 27, 'min_samples_split': 5, 'min_samples_leaf': 5}. Best is trial 7 with value: 0.4516331438256021.
# [I 2026-03-06 16:30:11,987] Trial 22 finished with value: 0.8106178685238694 and parameters: {'max_depth': 21, 'min_samples_split': 18, 'min_samples_leaf': 2}. Best is trial 7 with value: 0.4516331438256021.
# [I 2026-03-06 16:30:12,045] Trial 23 finished with value: 0.30618659933697484 and parameters: {'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 23 with value: 0.30618659933697484.
# [I 2026-03-06 16:30:12,102] Trial 24 finished with value: 0.30609750633467414 and parameters: {'max_depth': 31, 'min_samples_split': 11, 'min_samples_leaf': 1}. Best is trial 24 with value: 0.30609750633467414.
# [I 2026-03-06 16:30:12,158] Trial 25 finished with value: 0.30609750633467414 and parameters: {'max_depth': 31, 'min_samples_split': 11, 'min_samples_leaf': 1}. Best is trial 24 with value: 0.30609750633467414.
# [I 2026-03-06 16:30:12,212] Trial 26 finished with value: 0.30618659933697484 and parameters: {'max_depth': 31, 'min_samples_split': 10, 'min_samples_leaf': 2}. Best is trial 24 with value: 0.30609750633467414.
# [I 2026-03-06 16:30:12,289] Trial 27 finished with value: 0.24911227766423796 and parameters: {'max_depth': 32, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 27 with value: 0.24911227766423796.
# [I 2026-03-06 16:30:12,364] Trial 28 finished with value: 0.2450758790430362 and parameters: {'max_depth': 33, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 28 with value: 0.2450758790430362.
# [I 2026-03-06 16:30:12,442] Trial 29 finished with value: 0.745327078070171 and parameters: {'max_depth': 34, 'min_samples_split': 2, 'min_samples_leaf': 6}. Best is trial 28 with value: 0.2450758790430362.
# [I 2026-03-06 16:30:12,520] Trial 30 finished with value: 0.8251575663581395 and parameters: {'max_depth': 37, 'min_samples_split': 6, 'min_samples_leaf': 7}. Best is trial 28 with value: 0.2450758790430362.
# [I 2026-03-06 16:30:12,583] Trial 31 finished with value: 0.24911227766423796 and parameters: {'max_depth': 33, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 28 with value: 0.2450758790430362.
# [I 2026-03-06 16:30:12,645] Trial 32 finished with value: 0.2450758790430362 and parameters: {'max_depth': 32, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 28 with value: 0.2450758790430362.
# [I 2026-03-06 16:30:12,721] Trial 33 finished with value: 0.2450758790430362 and parameters: {'max_depth': 40, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 28 with value: 0.2450758790430362.
# [I 2026-03-06 16:30:12,795] Trial 34 finished with value: 0.8251575663581395 and parameters: {'max_depth': 39, 'min_samples_split': 4, 'min_samples_leaf': 7}. Best is trial 28 with value: 0.2450758790430362.
# [I 2026-03-06 16:30:12,877] Trial 35 finished with value: 0.2450758790430362 and parameters: {'max_depth': 38, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 28 with value: 0.2450758790430362.
# [I 2026-03-06 16:30:12,941] Trial 36 finished with value: 0.593922593539829 and parameters: {'max_depth': 38, 'min_samples_split': 3, 'min_samples_leaf': 5}. Best is trial 28 with value: 0.2450758790430362.
# [I 2026-03-06 16:30:13,001] Trial 37 finished with value: 2.2603257591846417 and parameters: {'max_depth': 36, 'min_samples_split': 4, 'min_samples_leaf': 15}. Best is trial 28 with value: 0.2450758790430362.
# [I 2026-03-06 16:30:13,060] Trial 38 finished with value: 1.1544711301897403 and parameters: {'max_depth': 40, 'min_samples_split': 2, 'min_samples_leaf': 11}. Best is trial 28 with value: 0.2450758790430362.
# [I 2026-03-06 16:30:13,118] Trial 39 finished with value: 0.745327078070171 and parameters: {'max_depth': 35, 'min_samples_split': 8, 'min_samples_leaf': 6}. Best is trial 28 with value: 0.2450758790430362.
# [I 2026-03-06 16:30:13,127] A new study created in memory with name: knn_M_LB
# [I 2026-03-06 16:30:13,181] Trial 0 finished with value: 2.6638090694747474 and parameters: {'n_neighbors': 18, 'weights': 'distance', 'p': 1}. Best is trial 0 with value: 2.6638090694747474.
# [I 2026-03-06 16:30:13,227] Trial 1 finished with value: 2.6890375414836813 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 2.6638090694747474.
# [I 2026-03-06 16:30:13,278] Trial 2 finished with value: 3.9954417491613285 and parameters: {'n_neighbors': 32, 'weights': 'distance', 'p': 2}. Best is trial 0 with value: 2.6638090694747474.
# === Tuning KNN for M_LB ===
# [I 2026-03-06 16:30:13,334] Trial 3 finished with value: 4.306969054753945 and parameters: {'n_neighbors': 31, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 2.6638090694747474.
# [I 2026-03-06 16:30:13,389] Trial 4 finished with value: 3.592853492052746 and parameters: {'n_neighbors': 21, 'weights': 'distance', 'p': 2}. Best is trial 0 with value: 2.6638090694747474.
# [I 2026-03-06 16:30:13,442] Trial 5 finished with value: 4.057228882792623 and parameters: {'n_neighbors': 34, 'weights': 'distance', 'p': 2}. Best is trial 0 with value: 2.6638090694747474.
# [I 2026-03-06 16:30:13,487] Trial 6 finished with value: 2.2816237080676935 and parameters: {'n_neighbors': 6, 'weights': 'distance', 'p': 1}. Best is trial 6 with value: 2.2816237080676935.
# [I 2026-03-06 16:30:13,532] Trial 7 finished with value: 3.7142590059288936 and parameters: {'n_neighbors': 32, 'weights': 'uniform', 'p': 1}. Best is trial 6 with value: 2.2816237080676935.
# [I 2026-03-06 16:30:13,590] Trial 8 finished with value: 2.977262571619696 and parameters: {'n_neighbors': 17, 'weights': 'uniform', 'p': 1}. Best is trial 6 with value: 2.2816237080676935.
# [I 2026-03-06 16:30:13,654] Trial 9 finished with value: 4.263895450375921 and parameters: {'n_neighbors': 30, 'weights': 'uniform', 'p': 2}. Best is trial 6 with value: 2.2816237080676935.
# [I 2026-03-06 16:30:13,730] Trial 10 finished with value: 2.025475160535286 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 2.025475160535286.
# [I 2026-03-06 16:30:13,809] Trial 11 finished with value: 2.4784987909061753 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 2.025475160535286.
# [I 2026-03-06 16:30:13,887] Trial 12 finished with value: 2.3889362441032005 and parameters: {'n_neighbors': 9, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 2.025475160535286.
# [I 2026-03-06 16:30:13,965] Trial 13 finished with value: 2.4122623741848654 and parameters: {'n_neighbors': 8, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 2.025475160535286.
# [I 2026-03-06 16:30:14,050] Trial 14 finished with value: 2.3889362441032005 and parameters: {'n_neighbors': 9, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 2.025475160535286.
# [I 2026-03-06 16:30:14,141] Trial 15 finished with value: 2.4228525086612853 and parameters: {'n_neighbors': 13, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 2.025475160535286.
# [I 2026-03-06 16:30:14,229] Trial 16 finished with value: 2.1598284387491473 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 2.025475160535286.
# [I 2026-03-06 16:30:14,315] Trial 17 finished with value: 2.8583521179144578 and parameters: {'n_neighbors': 24, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 2.025475160535286.
# [I 2026-03-06 16:30:14,407] Trial 18 finished with value: 2.4228525086612853 and parameters: {'n_neighbors': 13, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 2.025475160535286.
# [I 2026-03-06 16:30:14,507] Trial 19 finished with value: 2.1598284387491473 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 2.025475160535286.
# [I 2026-03-06 16:30:14,602] Trial 20 finished with value: 3.2529559655874705 and parameters: {'n_neighbors': 14, 'weights': 'distance', 'p': 2}. Best is trial 10 with value: 2.025475160535286.
# [I 2026-03-06 16:30:14,687] Trial 21 finished with value: 2.1598284387491473 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 2.025475160535286.
# [I 2026-03-06 16:30:14,765] Trial 22 finished with value: 2.1598284387491473 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 2.025475160535286.
# [I 2026-03-06 16:30:14,848] Trial 23 finished with value: 2.4784987909061753 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 2.025475160535286.
# [I 2026-03-06 16:30:14,939] Trial 24 finished with value: 2.330887768394951 and parameters: {'n_neighbors': 11, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 2.025475160535286.
# [I 2026-03-06 16:30:15,011] Trial 25 finished with value: 2.2816237080676935 and parameters: {'n_neighbors': 6, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 2.025475160535286.
# [I 2026-03-06 16:30:15,079] Trial 26 finished with value: 3.4395591142930115 and parameters: {'n_neighbors': 26, 'weights': 'uniform', 'p': 1}. Best is trial 10 with value: 2.025475160535286.
# [I 2026-03-06 16:30:15,144] Trial 27 finished with value: 1.9447612977842783 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'p': 1}. Best is trial 27 with value: 1.9447612977842783.
# [I 2026-03-06 16:30:15,205] Trial 28 finished with value: 2.4122623741848654 and parameters: {'n_neighbors': 8, 'weights': 'distance', 'p': 1}. Best is trial 27 with value: 1.9447612977842783.
# [I 2026-03-06 16:30:15,269] Trial 29 finished with value: 2.6316363374784926 and parameters: {'n_neighbors': 17, 'weights': 'distance', 'p': 1}. Best is trial 27 with value: 1.9447612977842783.
# [I 2026-03-06 16:30:15,336] Trial 30 finished with value: 1.9447612977842783 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'p': 1}. Best is trial 27 with value: 1.9447612977842783.
# [I 2026-03-06 16:30:15,416] Trial 31 finished with value: 1.9447612977842783 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'p': 1}. Best is trial 27 with value: 1.9447612977842783.
# [I 2026-03-06 16:30:15,503] Trial 32 finished with value: 2.4784987909061753 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 1}. Best is trial 27 with value: 1.9447612977842783.
# [I 2026-03-06 16:30:15,590] Trial 33 finished with value: 2.330887768394951 and parameters: {'n_neighbors': 11, 'weights': 'distance', 'p': 1}. Best is trial 27 with value: 1.9447612977842783.
# [I 2026-03-06 16:30:15,656] Trial 34 finished with value: 2.1180130541008255 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 1}. Best is trial 27 with value: 1.9447612977842783.
# [I 2026-03-06 16:30:15,721] Trial 35 finished with value: 2.3728514993107894 and parameters: {'n_neighbors': 7, 'weights': 'distance', 'p': 1}. Best is trial 27 with value: 1.9447612977842783.
# [I 2026-03-06 16:30:15,785] Trial 36 finished with value: 3.5917175308636344 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'p': 2}. Best is trial 27 with value: 1.9447612977842783.
# [I 2026-03-06 16:30:15,849] Trial 37 finished with value: 2.330887768394951 and parameters: {'n_neighbors': 11, 'weights': 'distance', 'p': 1}. Best is trial 27 with value: 1.9447612977842783.
# [I 2026-03-06 16:30:15,928] Trial 38 finished with value: 4.332637586203083 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'p': 2}. Best is trial 27 with value: 1.9447612977842783.
# [I 2026-03-06 16:30:16,000] Trial 39 finished with value: 2.7078879315559865 and parameters: {'n_neighbors': 20, 'weights': 'distance', 'p': 1}. Best is trial 27 with value: 1.9447612977842783.
# [I 2026-03-06 16:30:16,014] A new study created in memory with name: svr_M_LB
# [I 2026-03-06 16:30:16,146] Trial 0 finished with value: 0.6006837091820059 and parameters: {'C': 5.645756655349514, 'epsilon': 0.005842919735711235, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 0 with value: 0.6006837091820059.
# === Tuning SVR for M_LB ===
# [I 2026-03-06 16:30:16,254] Trial 1 finished with value: 7.845168986616207 and parameters: {'C': 0.19719456853981127, 'epsilon': 0.0010326966491503982, 'gamma': 'auto', 'kernel': 'rbf'}. Best is trial 0 with value: 0.6006837091820059.
# [I 2026-03-06 16:30:16,354] Trial 2 finished with value: 7.967301898629262 and parameters: {'C': 0.21160295114447056, 'epsilon': 0.002560578739011345, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 0 with value: 0.6006837091820059.
# [I 2026-03-06 16:30:16,461] Trial 3 finished with value: 10.248341792007142 and parameters: {'C': 0.07634767302667424, 'epsilon': 0.25832422910183056, 'gamma': 'auto', 'kernel': 'poly'}. Best is trial 0 with value: 0.6006837091820059.
# [I 2026-03-06 16:30:17,026] Trial 4 finished with value: 2.9219016727125764 and parameters: {'C': 45.96676031437899, 'epsilon': 0.09788409318882928, 'gamma': 'scale', 'kernel': 'poly'}. Best is trial 0 with value: 0.6006837091820059.
# [I 2026-03-06 16:30:17,087] Trial 5 finished with value: 10.366938489435785 and parameters: {'C': 0.02588440956310344, 'epsilon': 0.28745543449797345, 'gamma': 'scale', 'kernel': 'poly'}. Best is trial 0 with value: 0.6006837091820059.
# [I 2026-03-06 16:30:17,154] Trial 6 finished with value: 4.475189323519828 and parameters: {'C': 4.949109363618294, 'epsilon': 0.35769087921830983, 'gamma': 'auto', 'kernel': 'sigmoid'}. Best is trial 0 with value: 0.6006837091820059.
# [I 2026-03-06 16:30:17,240] Trial 7 finished with value: 3.384463142621965 and parameters: {'C': 17.79804627633078, 'epsilon': 0.4360324275612871, 'gamma': 'auto', 'kernel': 'poly'}. Best is trial 0 with value: 0.6006837091820059.
# [I 2026-03-06 16:30:17,361] Trial 8 finished with value: 4.158668762648552 and parameters: {'C': 2.801351161860159, 'epsilon': 0.11339543156017864, 'gamma': 'scale', 'kernel': 'poly'}. Best is trial 0 with value: 0.6006837091820059.
# [I 2026-03-06 16:30:17,486] Trial 9 finished with value: 6.145977748031794 and parameters: {'C': 6.679046614436493, 'epsilon': 0.03939537548645813, 'gamma': 'auto', 'kernel': 'sigmoid'}. Best is trial 0 with value: 0.6006837091820059.
# [I 2026-03-06 16:30:18,002] Trial 10 finished with value: 0.17537695560498212 and parameters: {'C': 910.4657271209712, 'epsilon': 0.006919600209004605, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 10 with value: 0.17537695560498212.
# [I 2026-03-06 16:30:18,487] Trial 11 finished with value: 0.175897652890892 and parameters: {'C': 977.949467769414, 'epsilon': 0.007268536330100885, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 10 with value: 0.17537695560498212.
# [I 2026-03-06 16:30:18,903] Trial 12 finished with value: 0.18130157765812835 and parameters: {'C': 955.6457568111402, 'epsilon': 0.010622026171371746, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 10 with value: 0.17537695560498212.
# [I 2026-03-06 16:30:19,299] Trial 13 finished with value: 0.18595025280673072 and parameters: {'C': 985.4510775374829, 'epsilon': 0.013633125873665037, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 10 with value: 0.17537695560498212.
# [I 2026-03-06 16:30:19,962] Trial 14 finished with value: 0.17002341843284782 and parameters: {'C': 180.42544019832414, 'epsilon': 0.0032054658458519447, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 14 with value: 0.17002341843284782.
# [I 2026-03-06 16:30:20,701] Trial 15 finished with value: 0.16864624492234767 and parameters: {'C': 112.8156984916694, 'epsilon': 0.002023902672658104, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 15 with value: 0.16864624492234767.
# [I 2026-03-06 16:30:21,447] Trial 16 finished with value: 0.16808928532200515 and parameters: {'C': 125.57261655154844, 'epsilon': 0.0015826291187469451, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 16 with value: 0.16808928532200515.
# [I 2026-03-06 16:30:21,532] Trial 17 finished with value: 210.00138973551483 and parameters: {'C': 109.70357253323526, 'epsilon': 0.0010790355161172276, 'gamma': 'scale', 'kernel': 'sigmoid'}. Best is trial 16 with value: 0.16808928532200515.
# [I 2026-03-06 16:30:21,620] Trial 18 finished with value: 0.9138379142686425 and parameters: {'C': 108.24330625249695, 'epsilon': 0.9929330994050415, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 16 with value: 0.16808928532200515.
# [I 2026-03-06 16:30:22,036] Trial 19 finished with value: 0.20511040122833918 and parameters: {'C': 25.56904951306714, 'epsilon': 0.002201623908136137, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 16 with value: 0.16808928532200515.
# [I 2026-03-06 16:30:22,113] Trial 20 finished with value: 3.9981723378083496 and parameters: {'C': 0.7512750189952913, 'epsilon': 0.022539482458914475, 'gamma': 'scale', 'kernel': 'sigmoid'}. Best is trial 16 with value: 0.16808928532200515.
# [I 2026-03-06 16:30:22,704] Trial 21 finished with value: 0.16976407509191466 and parameters: {'C': 202.445679717101, 'epsilon': 0.002972989502809972, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 16 with value: 0.16808928532200515.
# [I 2026-03-06 16:30:23,360] Trial 22 finished with value: 0.16843506087402457 and parameters: {'C': 176.77655067277166, 'epsilon': 0.0018633815521873428, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 16 with value: 0.16808928532200515.
# [I 2026-03-06 16:30:24,062] Trial 23 finished with value: 0.168073083865131 and parameters: {'C': 295.65739148610544, 'epsilon': 0.0015622027471728056, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 23 with value: 0.168073083865131.
# [I 2026-03-06 16:30:24,876] Trial 24 finished with value: 0.167977554852265 and parameters: {'C': 301.15735950728873, 'epsilon': 0.0014889996154407632, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 24 with value: 0.167977554852265.
# [I 2026-03-06 16:30:25,597] Trial 25 finished with value: 0.17142090415859576 and parameters: {'C': 343.5510491830915, 'epsilon': 0.004190469716866117, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 24 with value: 0.167977554852265.
# [I 2026-03-06 16:30:26,413] Trial 26 finished with value: 0.14825727986402346 and parameters: {'C': 41.19293450918262, 'epsilon': 0.0013226901554300747, 'gamma': 'auto', 'kernel': 'rbf'}. Best is trial 26 with value: 0.14825727986402346.
# [I 2026-03-06 16:30:27,093] Trial 27 finished with value: 0.16970870063810622 and parameters: {'C': 33.16026041558509, 'epsilon': 0.0012123718039785153, 'gamma': 'auto', 'kernel': 'rbf'}. Best is trial 26 with value: 0.14825727986402346.
# [I 2026-03-06 16:30:27,188] Trial 28 finished with value: 342.2489248788112 and parameters: {'C': 369.2138664716388, 'epsilon': 0.004232588086343647, 'gamma': 'auto', 'kernel': 'sigmoid'}. Best is trial 26 with value: 0.14825727986402346.
# [I 2026-03-06 16:30:27,465] Trial 29 finished with value: 0.2632067558918899 and parameters: {'C': 14.728449831909721, 'epsilon': 0.005179291996095052, 'gamma': 'auto', 'kernel': 'rbf'}. Best is trial 26 with value: 0.14825727986402346.
# [I 2026-03-06 16:30:27,891] Trial 30 finished with value: 0.15601426372864338 and parameters: {'C': 65.59565475327204, 'epsilon': 0.03059088975906567, 'gamma': 'auto', 'kernel': 'rbf'}. Best is trial 26 with value: 0.14825727986402346.
# [I 2026-03-06 16:30:28,129] Trial 31 finished with value: 0.18539451253311828 and parameters: {'C': 55.017360732563326, 'epsilon': 0.060282910427170086, 'gamma': 'auto', 'kernel': 'rbf'}. Best is trial 26 with value: 0.14825727986402346.
# [I 2026-03-06 16:30:28,620] Trial 32 finished with value: 0.1443252023951272 and parameters: {'C': 366.10685857680744, 'epsilon': 0.02311257180586504, 'gamma': 'auto', 'kernel': 'rbf'}. Best is trial 32 with value: 0.1443252023951272.
# [I 2026-03-06 16:30:29,068] Trial 33 finished with value: 0.15212374034483037 and parameters: {'C': 58.025897431471805, 'epsilon': 0.02307321937700205, 'gamma': 'auto', 'kernel': 'rbf'}. Best is trial 32 with value: 0.1443252023951272.
# [I 2026-03-06 16:30:29,281] Trial 34 finished with value: 0.3272801743414236 and parameters: {'C': 10.875030468060144, 'epsilon': 0.026784978809909925, 'gamma': 'auto', 'kernel': 'rbf'}. Best is trial 32 with value: 0.1443252023951272.
# [I 2026-03-06 16:30:29,787] Trial 35 finished with value: 0.1508095876724803 and parameters: {'C': 50.73926400646718, 'epsilon': 0.016599447734356985, 'gamma': 'auto', 'kernel': 'rbf'}. Best is trial 32 with value: 0.1443252023951272.
# [I 2026-03-06 16:30:29,886] Trial 36 finished with value: 1.868905487736707 and parameters: {'C': 1.4355097638802023, 'epsilon': 0.01668138691079251, 'gamma': 'auto', 'kernel': 'rbf'}. Best is trial 32 with value: 0.1443252023951272.
# [I 2026-03-06 16:30:30,060] Trial 37 finished with value: 3.1182040701590914 and parameters: {'C': 37.10552004570739, 'epsilon': 0.05100840776094553, 'gamma': 'auto', 'kernel': 'poly'}. Best is trial 32 with value: 0.1443252023951272.
# [I 2026-03-06 16:30:30,206] Trial 38 finished with value: 0.43120076680250446 and parameters: {'C': 8.4325253795541, 'epsilon': 0.0957300502261852, 'gamma': 'auto', 'kernel': 'rbf'}. Best is trial 32 with value: 0.1443252023951272.
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [I 2026-03-06 16:58:10,766] A new study created in memory with name: catboost_M_DB
# === Tuning CATBOOST for M_DB ===
# [I 2026-03-06 16:58:14,112] Trial 0 finished with value: 0.25731207219199054 and parameters: {'depth': 8, 'learning_rate': 0.048254642143838636, 'l2_leaf_reg': 2.5162137493402232, 'n_estimators': 700}. Best is trial 0 with value: 0.25731207219199054.
# [I 2026-03-06 16:58:17,504] Trial 1 finished with value: 0.9610109023470098 and parameters: {'depth': 6, 'learning_rate': 0.0035106122736980835, 'l2_leaf_reg': 5.843862942402507, 'n_estimators': 1100}. Best is trial 0 with value: 0.25731207219199054.
# [I 2026-03-06 16:58:23,135] Trial 2 finished with value: 0.4495541870756227 and parameters: {'depth': 9, 'learning_rate': 0.003221205444708461, 'l2_leaf_reg': 1.8237514129785022, 'n_estimators': 1600}. Best is trial 0 with value: 0.25731207219199054.
# [I 2026-03-06 16:58:26,849] Trial 3 finished with value: 0.1706191239173646 and parameters: {'depth': 5, 'learning_rate': 0.0284752064144242, 'l2_leaf_reg': 9.171211582579858, 'n_estimators': 1600}. Best is trial 3 with value: 0.1706191239173646.
# [I 2026-03-06 16:58:28,258] Trial 4 finished with value: 0.24968306069348284 and parameters: {'depth': 6, 'learning_rate': 0.28374246666725683, 'l2_leaf_reg': 7.4735441939973875, 'n_estimators': 400}. Best is trial 3 with value: 0.1706191239173646.
# [I 2026-03-06 16:58:31,845] Trial 5 finished with value: 0.32209555890632774 and parameters: {'depth': 8, 'learning_rate': 0.19192888138475367, 'l2_leaf_reg': 8.848225211774457, 'n_estimators': 800}. Best is trial 3 with value: 0.1706191239173646.
# [I 2026-03-06 16:58:35,621] Trial 6 finished with value: 1.263654925604296 and parameters: {'depth': 5, 'learning_rate': 0.002261603690677003, 'l2_leaf_reg': 9.332262797932646, 'n_estimators': 1600}. Best is trial 3 with value: 0.1706191239173646.
# [I 2026-03-06 16:58:38,731] Trial 7 finished with value: 0.18054819745007297 and parameters: {'depth': 6, 'learning_rate': 0.07122102835205421, 'l2_leaf_reg': 2.242145950344778, 'n_estimators': 1000}. Best is trial 3 with value: 0.1706191239173646.
# [I 2026-03-06 16:58:48,577] Trial 8 finished with value: 0.37364145051737135 and parameters: {'depth': 9, 'learning_rate': 0.15177772780419277, 'l2_leaf_reg': 7.230512380064794, 'n_estimators': 1700}. Best is trial 3 with value: 0.1706191239173646.
# [I 2026-03-06 16:58:54,196] Trial 9 finished with value: 0.320831835447132 and parameters: {'depth': 9, 'learning_rate': 0.11010721554032243, 'l2_leaf_reg': 2.453311663184446, 'n_estimators': 1000}. Best is trial 3 with value: 0.1706191239173646.
# [I 2026-03-06 16:58:58,143] Trial 10 finished with value: 0.16957018038075508 and parameters: {'depth': 4, 'learning_rate': 0.016669904238650772, 'l2_leaf_reg': 4.269337037552327, 'n_estimators': 1900}. Best is trial 10 with value: 0.16957018038075508.
# [I 2026-03-06 16:59:02,537] Trial 11 finished with value: 0.1974459168735374 and parameters: {'depth': 4, 'learning_rate': 0.011276424381706288, 'l2_leaf_reg': 4.394745982559898, 'n_estimators': 2000}. Best is trial 10 with value: 0.16957018038075508.
# [I 2026-03-06 16:59:06,707] Trial 12 finished with value: 0.14995289018217314 and parameters: {'depth': 4, 'learning_rate': 0.024085963805726272, 'l2_leaf_reg': 4.537416440699618, 'n_estimators': 2000}. Best is trial 12 with value: 0.14995289018217314.
# [I 2026-03-06 16:59:10,814] Trial 13 finished with value: 0.19948514228899022 and parameters: {'depth': 4, 'learning_rate': 0.011026440666904926, 'l2_leaf_reg': 4.253304677535311, 'n_estimators': 2000}. Best is trial 12 with value: 0.14995289018217314.
# [I 2026-03-06 16:59:13,627] Trial 14 finished with value: 0.1760457709240507 and parameters: {'depth': 4, 'learning_rate': 0.02021737866446083, 'l2_leaf_reg': 4.081498046357994, 'n_estimators': 1400}. Best is trial 12 with value: 0.14995289018217314.
# [I 2026-03-06 16:59:18,529] Trial 15 finished with value: 2.4895983615923827 and parameters: {'depth': 5, 'learning_rate': 0.0010203965003735805, 'l2_leaf_reg': 5.532360023138173, 'n_estimators': 1900}. Best is trial 12 with value: 0.14995289018217314.
# [I 2026-03-06 16:59:24,716] Trial 16 finished with value: 0.2568201880366824 and parameters: {'depth': 7, 'learning_rate': 0.0075095261777438724, 'l2_leaf_reg': 3.4351891027585246, 'n_estimators': 1800}. Best is trial 12 with value: 0.14995289018217314.
# [I 2026-03-06 16:59:27,945] Trial 17 finished with value: 0.1555417691280307 and parameters: {'depth': 4, 'learning_rate': 0.035798348349279606, 'l2_leaf_reg': 6.7658737272524005, 'n_estimators': 1300}. Best is trial 12 with value: 0.14995289018217314.
# [I 2026-03-06 16:59:31,326] Trial 18 finished with value: 0.14624071552939627 and parameters: {'depth': 5, 'learning_rate': 0.04954173192569149, 'l2_leaf_reg': 6.773636553582365, 'n_estimators': 1300}. Best is trial 18 with value: 0.14624071552939627.
# [I 2026-03-06 16:59:32,202] Trial 19 finished with value: 0.15417770591465396 and parameters: {'depth': 5, 'learning_rate': 0.07056227048747175, 'l2_leaf_reg': 1.0443410173907104, 'n_estimators': 300}. Best is trial 18 with value: 0.14624071552939627.
# [I 2026-03-06 16:59:37,410] Trial 20 finished with value: 0.2339622713045686 and parameters: {'depth': 7, 'learning_rate': 0.056894771338418346, 'l2_leaf_reg': 6.455215898828469, 'n_estimators': 1400}. Best is trial 18 with value: 0.14624071552939627.
# [I 2026-03-06 16:59:38,471] Trial 21 finished with value: 0.15635447613904413 and parameters: {'depth': 5, 'learning_rate': 0.07222296028858495, 'l2_leaf_reg': 1.2696918357538869, 'n_estimators': 400}. Best is trial 18 with value: 0.14624071552939627.
# [I 2026-03-06 16:59:40,016] Trial 22 finished with value: 0.15194018210132992 and parameters: {'depth': 5, 'learning_rate': 0.1007706851610061, 'l2_leaf_reg': 7.718449957128583, 'n_estimators': 600}. Best is trial 18 with value: 0.14624071552939627.
# [I 2026-03-06 16:59:42,226] Trial 23 finished with value: 0.20217420551534587 and parameters: {'depth': 6, 'learning_rate': 0.11299845249092277, 'l2_leaf_reg': 8.238220985760845, 'n_estimators': 700}. Best is trial 18 with value: 0.14624071552939627.
# [I 2026-03-06 16:59:44,479] Trial 24 finished with value: 0.27961501156721225 and parameters: {'depth': 7, 'learning_rate': 0.029931966735419094, 'l2_leaf_reg': 7.913938408729397, 'n_estimators': 600}. Best is trial 18 with value: 0.14624071552939627.
# [I 2026-03-06 16:59:47,393] Trial 25 finished with value: 0.19631661864806765 and parameters: {'depth': 5, 'learning_rate': 0.019886459618744655, 'l2_leaf_reg': 6.339265326929776, 'n_estimators': 1200}. Best is trial 18 with value: 0.14624071552939627.
# [I 2026-03-06 16:59:49,185] Trial 26 finished with value: 0.17525531579815082 and parameters: {'depth': 4, 'learning_rate': 0.03857700868888683, 'l2_leaf_reg': 5.27142556746551, 'n_estimators': 800}. Best is trial 18 with value: 0.14624071552939627.
# [I 2026-03-06 16:59:53,663] Trial 27 finished with value: 0.19318873689094077 and parameters: {'depth': 6, 'learning_rate': 0.11314947280501593, 'l2_leaf_reg': 5.134696563513093, 'n_estimators': 1400}. Best is trial 18 with value: 0.14624071552939627.
# [I 2026-03-06 16:59:56,525] Trial 28 finished with value: 0.13180966565923496 and parameters: {'depth': 5, 'learning_rate': 0.29754773227574743, 'l2_leaf_reg': 8.600861032023605, 'n_estimators': 900}. Best is trial 28 with value: 0.13180966565923496.
# [I 2026-03-06 17:00:05,107] Trial 29 finished with value: 0.5340288522520555 and parameters: {'depth': 10, 'learning_rate': 0.2315518574512315, 'l2_leaf_reg': 9.78778397515177, 'n_estimators': 900}. Best is trial 28 with value: 0.13180966565923496.
# [I 2026-03-06 17:00:08,954] Trial 30 finished with value: 0.3591672202256893 and parameters: {'depth': 4, 'learning_rate': 0.007467456360227756, 'l2_leaf_reg': 8.475889716960953, 'n_estimators': 1200}. Best is trial 28 with value: 0.13180966565923496.
# [I 2026-03-06 17:00:11,190] Trial 31 finished with value: 0.13842978630198152 and parameters: {'depth': 5, 'learning_rate': 0.15308826699679065, 'l2_leaf_reg': 7.615531510242372, 'n_estimators': 600}. Best is trial 28 with value: 0.13180966565923496.
# [I 2026-03-06 17:00:13,615] Trial 32 finished with value: 0.136371730853826 and parameters: {'depth': 5, 'learning_rate': 0.20051387910958127, 'l2_leaf_reg': 7.080665273901936, 'n_estimators': 600}. Best is trial 28 with value: 0.13180966565923496.
# [I 2026-03-06 17:00:16,570] Trial 33 finished with value: 0.21613082600855452 and parameters: {'depth': 6, 'learning_rate': 0.16694458537517154, 'l2_leaf_reg': 7.019956966831319, 'n_estimators': 600}. Best is trial 28 with value: 0.13180966565923496.
# [I 2026-03-06 17:00:18,079] Trial 34 finished with value: 0.12957700319536342 and parameters: {'depth': 5, 'learning_rate': 0.29991039712890605, 'l2_leaf_reg': 6.100391985181993, 'n_estimators': 500}. Best is trial 34 with value: 0.12957700319536342.
# [I 2026-03-06 17:00:19,882] Trial 35 finished with value: 0.25580150239195865 and parameters: {'depth': 6, 'learning_rate': 0.2967568549601157, 'l2_leaf_reg': 6.195027835535498, 'n_estimators': 500}. Best is trial 34 with value: 0.12957700319536342.
# [I 2026-03-06 17:00:21,189] Trial 36 finished with value: 0.27364470847273076 and parameters: {'depth': 7, 'learning_rate': 0.22640880839467256, 'l2_leaf_reg': 8.74644520951277, 'n_estimators': 300}. Best is trial 34 with value: 0.12957700319536342.
# [I 2026-03-06 17:00:23,598] Trial 37 finished with value: 0.1358669415412312 and parameters: {'depth': 5, 'learning_rate': 0.1512609727514362, 'l2_leaf_reg': 8.068274782012374, 'n_estimators': 800}. Best is trial 34 with value: 0.12957700319536342.
# [I 2026-03-06 17:00:27,344] Trial 38 finished with value: 0.3347765400803076 and parameters: {'depth': 8, 'learning_rate': 0.2851579129643652, 'l2_leaf_reg': 9.994950649245485, 'n_estimators': 800}. Best is trial 34 with value: 0.12957700319536342.
# [I 2026-03-06 17:00:30,077] Trial 39 finished with value: 0.13124280465491417 and parameters: {'depth': 5, 'learning_rate': 0.19338595226645272, 'l2_leaf_reg': 9.329557906631102, 'n_estimators': 1000}. Best is trial 34 with value: 0.12957700319536342.
# [done] M_DB: saved ./artifacts\results_M_DB.json and ./artifacts\results_M_DB.csv
#
# === Leaderboard (lowest RMSE) for M_LB ===
#               rmse       mae        r2
# xgb       0.092624  0.065732  0.999942
# gbrt      0.098298  0.066198  0.999935
# catboost  0.098382  0.070373  0.999935
# lgbm      0.104605  0.078608  0.999926
# gpr       0.112974  0.082704  0.999914
# svr       0.177238  0.121846  0.999788
# rf         0.22493  0.153323  0.999658
# dt        0.246267  0.157803   0.99959
# knn       1.977157  1.415295  0.973574
# adaboost  2.214881  1.898878  0.966837
# === Leaderboard (lowest RMSE) for M_DB ===
#               rmse       mae        r2
# catboost  0.266203  0.089183   0.99928
# gbrt      0.285287  0.091952  0.999173
# xgb       0.290653  0.114747  0.999142
# rf        0.300206  0.171455  0.999084
# lgbm      0.306545  0.116578  0.999045
# svr       0.342444  0.154086  0.998809
# gpr        0.35221   0.20008   0.99874
# dt        0.385634  0.217387  0.998489
# knn       1.500157  1.092767  0.977138
# adaboost  1.666349  1.373374  0.971792

# %%
def choose_group_holdout(series, min_frac=0.12, max_frac=0.35):
    # pick a discrete value group to hold out with enough samples
    vc = series.value_counts(dropna=True)
    n = len(series)
    candidates = []
    for val, cnt in vc.items():
        frac = cnt / n
        if min_frac <= frac <= max_frac:
            candidates.append((abs(frac-0.2), val, cnt, frac))
    if candidates:
        candidates.sort()
        _, val, cnt, frac = candidates[0]
        return val, cnt, frac
    # fallback: hold out the most frequent value if nothing matches
    val = vc.index[0]
    cnt = int(vc.iloc[0])
    frac = cnt / n
    return val, cnt, frac

def split_conformal_intervals(model_pipe, X_train, y_train, X_test, alpha=0.1, calib_size=0.2, random_state=42):
    # Split train into train/calibration
    X_tr, X_cal, y_tr, y_cal = train_test_split(
        X_train, y_train, test_size=calib_size, random_state=random_state
    )
    model_pipe.fit(X_tr, y_tr)
    pred_cal = model_pipe.predict(X_cal)
    resid = np.abs(y_cal - pred_cal)

    n = len(resid)
    # split conformal quantile
    q = np.quantile(resid, np.ceil((n + 1) * (1 - alpha)) / n, method="higher" if hasattr(np, "quantile") else "linear")
    pred_test = model_pipe.predict(X_test)
    lo = pred_test - q
    hi = pred_test + q
    return pred_test, lo, hi, q

# %%
def ood_split_geometry(df, q=0.15):
    if "D" not in df.columns or "t" not in df.columns:
        raise ValueError("Need columns D and t for geometry OOD split.")
    slender = (df["D"].astype(float) / df["t"].astype(float))
    lo = slender.quantile(q)
    hi = slender.quantile(1 - q)
    is_test = (slender <= lo) | (slender >= hi)
    meta = {"scenario":"OOD-Geometry", "proxy":"D/t", "q":float(q), "lo":float(lo), "hi":float(hi),
            "n_test":int(is_test.sum()), "test_frac":float(is_test.mean())}
    return is_test, meta

def ood_split_group(df, colname):
    if colname not in df.columns:
        raise ValueError(f"Need column {colname} for group OOD split.")
    val, cnt, frac = choose_group_holdout(df[colname])
    is_test = (df[colname] == val)
    meta = {"scenario":f"OOD-{colname}", "col":colname, "held_out":val,
            "n_test":int(cnt), "test_frac":float(frac)}
    return is_test, meta

# %%
def ood_split_geometry(df, q=0.15):
    if "D" not in df.columns or "t" not in df.columns:
        raise ValueError("Need columns D and t for geometry OOD split.")
    slender = (df["D"].astype(float) / df["t"].astype(float))
    lo = slender.quantile(q)
    hi = slender.quantile(1 - q)
    is_test = (slender <= lo) | (slender >= hi)
    meta = {"scenario":"OOD-Geometry", "proxy":"D/t", "q":float(q), "lo":float(lo), "hi":float(hi),
            "n_test":int(is_test.sum()), "test_frac":float(is_test.mean())}
    return is_test, meta

def ood_split_group(df, colname):
    if colname not in df.columns:
        raise ValueError(f"Need column {colname} for group OOD split.")
    val, cnt, frac = choose_group_holdout(df[colname])
    is_test = (df[colname] == val)
    meta = {"scenario":f"OOD-{colname}", "col":colname, "held_out":val,
            "n_test":int(cnt), "test_frac":float(frac)}
    return is_test, meta

# %%
# ====== SETUP + In-distribution (ID) evaluation (ALL-IN-ONE FIX) ======
import os
import numpy as np
import pandas as pd

# 1) Load dataset (edit path if needed)
DATA_PATH = "data/data.xlsx"   # or "data/data.xlsx" depending on your repo
df = pd.read_excel(DATA_PATH)

# 2) Define targets + feature columns
targets = ["M_LB", "M_DB"]
X_cols = [c for c in df.columns if c not in targets]

# 3) Random seed
RANDOM_STATE = 42

# 4) Run ID evaluation (expects fit_eval_id(...) already defined earlier)
X = df[X_cols].copy()
id_results = {}

for t in targets:
    y = df[t].astype(float).copy()
    res, fitted, splits = fit_eval_id(X, y, X_cols, test_size=0.2, random_state=RANDOM_STATE)
    id_results[t] = {"table": res, "models": fitted, "splits": splits}
    print(f"\nID results for {t} (sorted by MAE):")
    display(res)

# 5) Save ID tables
os.makedirs("outputs", exist_ok=True)
for t in targets:
    out_csv = f"outputs/id_results_{t}.csv"
    id_results[t]["table"].to_csv(out_csv, index=False)
    print("Saved:", out_csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 23
#      21 for t in targets:
#      22     y = df[t].astype(float).copy()
# ---> 23     res, fitted, splits = fit_eval_id(X, y, X_cols, test_size=0.2, random_state=RANDOM_STATE)
#      24     id_results[t] = {"table": res, "models": fitted, "splits": splits}
#      25     print(f"\nID results for {t} (sorted by MAE):")
#
# NameError: name 'fit_eval_id' is not defined

# %%
# ====== Figure: ID performance (MAE, RMSE, R2) with clean fonts ======
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

os.makedirs("figures", exist_ok=True)

# Consistent publication-style font
mpl.rcParams.update({
    "font.family": "Times New Roman",
    "font.size": 12,
    "font.weight": "bold",
    "axes.labelweight": "bold",
    "axes.titleweight": "bold",
    "axes.edgecolor": "black",
    "axes.linewidth": 1.4,
    "xtick.major.width": 1.2,
    "ytick.major.width": 1.2,
})

def save_bar(tab, metric, target, fname):
    tab = tab.sort_values(metric).reset_index(drop=True)
    x = np.arange(len(tab))

    plt.figure(figsize=(10, 4.4))
    plt.bar(x, tab[metric].values)  # default Matplotlib color cycle (no hard-coded colors)
    plt.xticks(x, tab["model"].values, rotation=25, ha="right")
    plt.ylabel(metric)
    plt.title(f"ID {metric} by model ({target})")
    plt.grid(axis="y", linestyle="--", linewidth=0.6, alpha=0.35)
    plt.tight_layout()
    plt.savefig(fname, dpi=300)
    plt.show()
    print("Saved:", fname)

for t in targets:
    tab = id_results[t]["table"].copy()

    # If your table uses "Model" instead of "model", uncomment:
    # tab = tab.rename(columns={"Model": "model"})

    save_bar(tab, "MAE", t, f"figures/id_MAE_{t}.png")
    save_bar(tab, "RMSE", t, f"figures/id_RMSE_{t}.png")
    save_bar(tab, "R2", t, f"figures/id_R2_{t}.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 37
#      34     plt.show()
#      35     print("Saved:", fname)
# ---> 37 for t in targets:
#      38     tab = id_results[t]["table"].copy()
#      40     # If your table uses "Model" instead of "model", uncomment:
#      41     # tab = tab.rename(columns={"Model": "model"})
#
# NameError: name 'targets' is not defined
